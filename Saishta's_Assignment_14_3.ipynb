# %% [markdown]
# <a href="https://colab.research.google.com/github/sai1519/My-projects-and-programs/blob/Machine-Learning/Saishta's_Assignment_14_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Program
# ## The data file contains numerical attributes that describe a letter and its corresponding class. Read the datafile “letterCG.data” and set all the numerical attributes as features. Split the data in to train and test sets.
#
# ## Fit a sequence of AdaBoostClassifier with varying number of weak learners ranging from 1 to 16, keeping the max_depth as 1. Plot the accuracy on test set against the number of weak learners. Use decision tree classifier as the base classifier.
#
# ## Repeat step2 with max_depth set as 2

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

data = pd.read_csv("letterCG.data", header = None, delimiter=" ")
data.columns =["Class"] + [f"Feature_{i}" for i in range(18)]
data.head()
# Out:
#    Class Feature_0 Feature_1 Feature_2 Feature_3  Feature_4 Feature_5  \
# 0  Class     x-box     y-box     width      high        NaN     onpix
# 1      C         4        10         5         8        2.0         5
# 2      C         3         5         4         4        2.0         4
# 3      G         5        10         6         7        3.0         8
# 4      C         5         9         6         7        4.0         3
#
#   Feature_6 Feature_7 Feature_8 Feature_9 Feature_10 Feature_11 Feature_12  \
# 0     x-bar     y-bar     x2bar     y2bar      xybar      x2ybr      xy2br
# 1         7         7        10         7          6         13          1
# 2         8         5         7        12          9         11          1
# 3         7         8         8         6          7          9          2
# 4         8         6         7        12         10         13          1
#
#   Feature_13 Feature_14 Feature_15 Feature_16  Feature_17
# ...

# %%
missing_values = data.isna().sum()
missing_values
# Out:
# Class         0
# Feature_0     0
# Feature_1     0
# Feature_2     0
# Feature_3     0
# Feature_4     1
# Feature_5     0
# Feature_6     0
# Feature_7     0
# Feature_8     0
# Feature_9     0
# Feature_10    0
# Feature_11    0
# Feature_12    0
# Feature_13    0
# Feature_14    0
# Feature_15    0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Class            0
# Feature_0        0
# Feature_1        0
# Feature_2        0
# Feature_3        0
# Feature_4        1
# Feature_5        0
# Feature_6        0
# Feature_7        0
# Feature_8        0
# Feature_9        0
# Feature_10       0
# Feature_11       0
# Feature_12       0
# Feature_13       0
# Feature_14       0
# Feature_15       0
# Feature_16    1509
# Feature_17    1510
# dtype: int64

# %%
data = data.drop(["Feature_16", "Feature_17"], axis =1)

# %%
x = data.iloc[:, 1: ]
y = data["Class"]

x_train,x_test,y_train,y_test = train_test_split(x,y, test_size= 0.2, random_state=42)

num_weak_learners= range(1,17)
accuracies_depth1= []
accuracies_depth2 = []

for n in num_weak_learners:
  clf_depth1 = AdaBoostClassifier(base_estimator = DecisionTreeClassifier(max_depth=1), n_estimators =n, random_state=42)
  clf_depth1.fit(x_train, y_train)
  y_pred_depth1 = clf_depth1.predict(x_test)
  accuracies_depth1.append(accuracy_score(y_test, y_pred_depth1))

    # Fit AdaBoost with max_depth=2
  clf_depth2 = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=2), n_estimators=n, random_state=42)
  clf_depth2.fit(x_train, y_train)
  y_pred_depth2 = clf_depth2.predict(x_test)
  accuracies_depth2.append(accuracy_score(y_test, y_pred_depth2))


plt.figure(figsize=(10,6))
plt.plot(range(1,17), accuracies_depth1, label="Max Depth = 1")
plt.plot(range(1,17), accuracies_depth2, label= "Max Depth =2")
plt.xlabel("Number of weal learners")
plt.ylabel("Accuracy on test set")
plt.title("AdaBoostClassifier Accuracy vs Number of weak Learners")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-b258b163fa48> in <cell line: 10>()
#      10 for n in num_weak_learners:
#      11   clf_depth1 = AdaBoostClassifier(base_estimator = DecisionTreeClassifier(max_depth=1), n_estimators =n, random_state=42)
# ---> 12   clf_depth1.fit(x_train, y_train)
#      13   y_pred_depth1 = clf_depth1.predict(x_test)
#      14   accuracies_depth1.append(accuracy_score(y_test, y_pred_depth1))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py in fit(self, X, y, sample_weight)
#     124         self._validate_params()
#     125
# --> 126         X, y = self._validate_data(
#     127             X,
#     128             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...
